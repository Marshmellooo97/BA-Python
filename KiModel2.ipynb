# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Input
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import psutil
import time
import csv

# %%
pfadData = '../Testdaten/final_df2_cleaned.csv'
data = pd.read_csv(pfadData)# , encoding='ISO-8859-1', delimiter=';', quoting=csv.QUOTE_ALL)
print(data.head())
# Out:
#    BOOKING_ID  Stromaufnahme.Geber.Ratio  Abgleichtemperatur.20G  \
# 0     1189360                   4.754602                  20.796
# 1     1181462                   5.025973                  21.280
# 2     1389916                   4.537733                  24.103
# 3     1189407                   4.502935                  20.916
# 4     1180717                   4.466320                  20.710
#
#    AbgleichMLX_MBA2_Abgleich...DigTv  AbgleichMLX_MBA2_Abgleich...DigTx  \
# 0                                347                                  0
# 1                                384                                  0
# 2                                617                                  0
# 3                                330                                  0
# 4                                291                                  0
#
#    AbgleichMLX_MBA2_Abgleich...DummyTempTv  \
# 0                                20.796000
# 1                                21.280001
# ...

# %%
X = data.drop('Gesamt_MEASURE_FAIL_CODE', axis=1)
Y = data['Gesamt_MEASURE_FAIL_CODE']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=101)
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = Sequential()
model.add(Dense(units=391, activation='relu'))
model.add(Dense(units=782, activation='relu'))
model.add(Dense(units=1564, activation='relu'))
model.add(Dense(units=1564, activation='relu'))
model.add(Dense(units=1564, activation='relu'))
model.add(Dense(units=1564, activation='relu'))
model.add(Dense(units=782, activation='relu'))
model.add(Dense(units=782, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model.fit(x=x_train, y=y_train, epochs=1000, validation_data=(x_test, y_test), verbose=1)
# Out:
# Epoch 1/200
# 1501/1501 [==============================] - 5s 3ms/step - loss: 0.3074 - val_loss: 0.3017
# Epoch 2/200
# 1501/1501 [==============================] - 4s 3ms/step - loss: 0.2744 - val_loss: 0.2626
# Epoch 3/200
# 1501/1501 [==============================] - 4s 3ms/step - loss: 0.2490 - val_loss: 0.2413
# Epoch 4/200
# 1501/1501 [==============================] - 4s 3ms/step - loss: 0.2340 - val_loss: 0.2206
# Epoch 5/200
# 1501/1501 [==============================] - 4s 3ms/step - loss: 0.2249 - val_loss: 0.2248
# Epoch 6/200
# 1501/1501 [==============================] - 4s 3ms/step - loss: 0.2247 - val_loss: 0.2328
# Epoch 7/200
# 1501/1501 [==============================] - 4s 3ms/step - loss: 0.2191 - val_loss: 0.2566
# Epoch 8/200
# 1501/1501 [==============================] - 4s 3ms/step - loss: 0.2118 - val_loss: 0.2080
# Epoch 9/200
# 1501/1501 [==============================] - 4s 3ms/step - loss: 0.2082 - val_loss: 0.2074
# Epoch 10/200
# ...

# %%
modelBaum = DecisionTreeClassifier(random_state=101)
modelBaum.fit(x_train, y_train)
y_pred = modelBaum.predict(x_test)

# Modell bewerten
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.9927518120469883
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     10935
#            1       0.99      0.99      0.99      5069
#
#     accuracy                           0.99     16004
#    macro avg       0.99      0.99      0.99     16004
# weighted avg       0.99      0.99      0.99     16004

# %%
pd.DataFrame(model.history.history).plot()
plt.show()
