# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Input
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import psutil
import time
import csv
# Out:
# 2024-08-29 23:40:23.665749: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-29 23:40:23.666784: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-29 23:40:23.669131: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-29 23:40:23.677785: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-29 23:40:23.693378: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-29 23:40:23.693445: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-29 23:40:23.703787: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-29 23:40:24.518333: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
x_train = pd.read_csv('../Testdaten/xTrain.csv')
x_test = pd.read_csv('../Testdaten/xTest.csv')
y_train = pd.read_csv('../Testdaten/yTrain.csv')
y_test = pd.read_csv('../Testdaten/yTest.csv')

# %%
modelBaum = DecisionTreeClassifier(random_state=101)
modelBaum.fit(x_train, y_train)
y_pred = modelBaum.predict(x_test)

# Modell bewerten
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")

conf_matrix = confusion_matrix(y_test, y_pred)
print(f"Confusion Matrix:\n{conf_matrix}")

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy: 0.992501562174547
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     13185
#            1       0.99      0.99      0.99      6019
#
#     accuracy                           0.99     19204
#    macro avg       0.99      0.99      0.99     19204
# weighted avg       0.99      0.99      0.99     19204
#
# Confusion Matrix:
# [[13128    57]
#  [   87  5932]]

# %%
bla = x_train.columns[0]

# %%
erList = []
for i in range(0, len(x_train)):
    manuellData = x_train.iloc[[i]]
    erg = y_train.iloc[i]  
    manuell = modelBaum.predict(manuellData)
    erList.append([manuell, erg])


print(erList)
# Out:
# [[array([0]), x    0
# Name: 0, dtype: int64], [array([0]), x    0
# Name: 1, dtype: int64], [array([0]), x    0
# Name: 2, dtype: int64], [array([0]), x    0
# Name: 3, dtype: int64], [array([0]), x    0
# Name: 4, dtype: int64], [array([0]), x    0
# Name: 5, dtype: int64], [array([0]), x    0
# Name: 6, dtype: int64], [array([0]), x    0
# Name: 7, dtype: int64], [array([0]), x    0
# Name: 8, dtype: int64], [array([0]), x    0
# Name: 9, dtype: int64], [array([0]), x    0
# Name: 10, dtype: int64], [array([1]), x    1
# Name: 11, dtype: int64], [array([0]), x    0
# Name: 12, dtype: int64], [array([0]), x    0
# Name: 13, dtype: int64], [array([0]), x    0
# Name: 14, dtype: int64], [array([0]), x    0
# Name: 15, dtype: int64], [array([0]), x    0
# Name: 16, dtype: int64], [array([0]), x    0
# Name: 17, dtype: int64], [array([0]), x    0
# Name: 18, dtype: int64], [array([0]), x    0
# Name: 19, dtype: int64], [array([0]), x    0
# Name: 20, dtype: int64], [array([0]), x    0
# Name: 21, dtype: int64], [array([0]), x    0
# Name: 22, dtype: int64], [array([0]), x    0
# Name: 23, dtype: int64], [array([0]), x    0
# Name: 24, dtype: int64], [array([0]), x    0
# Name: 25, dtype: int64], [array([0]), x    0
# Name: 26, dtype: int64], [array([0]), x    0
# Name: 27, dtype: int64], [array([0]), x    0
# Name: 28, dtype: int64], [array([0]), x    0
# Name: 29, dtype: int64], [array([0]), x    0
# Name: 30, dtype: int64], [array([0]), x    0
# Name: 31, dtype: int64], [array([0]), x    0
# Name: 32, dtype: int64], [array([0]), x    0
# Name: 33, dtype: int64], [array([0]), x    0
# Name: 34, dtype: int64], [array([0]), x    0
# Name: 35, dtype: int64], [array([0]), x    0
# Name: 36, dtype: int64], [array([0]), x    0
# Name: 37, dtype: int64], [array([0]), x    0
# Name: 38, dtype: int64], [array([0]), x    0
# Name: 39, dtype: int64], [array([0]), x    0
# Name: 40, dtype: int64], [array([0]), x    0
# Name: 41, dtype: int64], [array([0]), x    0
# Name: 42, dtype: int64], [array([0]), x    0
# Name: 43, dtype: int64], [array([0]), x    0
# Name: 44, dtype: int64], [array([0]), x    0
# Name: 45, dtype: int64], [array([1]), x    1
# Name: 46, dtype: int64], [array([0]), x    0
# Name: 47, dtype: int64], [array([0]), x    0
# Name: 48, dtype: int64], [array([1]), x    1
# Name: 49, dtype: int64], [array([1]), x    1
# Name: 50, dtype: int64], [array([1]), x    1
# Name: 51, dtype: int64], [array([1]), x    1
# Name: 52, dtype: int64], [array([1]), x    1
# Name: 53, dtype: int64], [array([1]), x    1
# Name: 54, dtype: int64], [array([1]), x    1
# Name: 55, dtype: int64], [array([0]), x    0
# Name: 56, dtype: int64], [array([0]), x    0
# Name: 57, dtype: int64], [array([0]), x    0
# Name: 58, dtype: int64], [array([0]), x    0
# Name: 59, dtype: int64], [array([0]), x    0
# Name: 60, dtype: int64], [array([0]), x    0
# Name: 61, dtype: int64], [array([0]), x    0
# Name: 62, dtype: int64], [array([0]), x    0
# Name: 63, dtype: int64], [array([0]), x    0
# Name: 64, dtype: int64], [array([0]), x    0
# Name: 65, dtype: int64], [array([0]), x    0
# Name: 66, dtype: int64], [array([0]), x    0
# Name: 67, dtype: int64], [array([0]), x    0
# Name: 68, dtype: int64], [array([0]), x    0
# Name: 69, dtype: int64], [array([1]), x    1
# Name: 70, dtype: int64], [array([0]), x    0
# Name: 71, dtype: int64], [array([1]), x    1
# Name: 72, dtype: int64], [array([1]), x    1
# Name: 73, dtype: int64], [array([1]), x    1
# Name: 74, dtype: int64], [array([1]), x    1
# Name: 75, dtype: int64], [array([0]), x    0
# Name: 76, dtype: int64], [array([1]), x    1
# Name: 77, dtype: int64], [array([1]), x    1
# Name: 78, dtype: int64], [array([1]), x    1
# Name: 79, dtype: int64], [array([0]), x    0
# Name: 80, dtype: int64], [array([1]), x    1
# Name: 81, dtype: int64], [array([1]), x    1
# Name: 82, dtype: int64], [array([1]), x    1
# Name: 83, dtype: int64], [array([1]), x    1
# Name: 84, dtype: int64], [array([1]), x    1
# Name: 85, dtype: int64], [array([1]), x    1
# Name: 86, dtype: int64], [array([1]), x    1
# Name: 87, dtype: int64], [array([1]), x    1
# Name: 88, dtype: int64], [array([1]), x    1
# Name: 89, dtype: int64], [array([1]), x    1
# Name: 90, dtype: int64], [array([1]), x    1
# Name: 91, dtype: int64], [array([1]), x    1
# Name: 92, dtype: int64], [array([1]), x    1
# Name: 93, dtype: int64], [array([1]), x    1
# Name: 94, dtype: int64], [array([0]), x    0
# Name: 95, dtype: int64], [array([0]), x    0
# Name: 96, dtype: int64], [array([0]), x    0
# Name: 97, dtype: int64], [array([0]), x    0
# Name: 98, dtype: int64], [array([0]), x    0
# Name: 99, dtype: int64], [array([0]), x    0
# Name: 100, dtype: int64], [array([0]), x    0
# Name: 101, dtype: int64], [array([0]), x    0
# Name: 102, dtype: int64], [array([0]), x    0
# Name: 103, dtype: int64], [array([0]), x    0
# Name: 104, dtype: int64], [array([0]), x    0
# Name: 105, dtype: int64], [array([0]), x    0
# Name: 106, dtype: int64], [array([0]), x    0
# Name: 107, dtype: int64], [array([1]), x    1
# Name: 108, dtype: int64], [array([0]), x    0
# Name: 109, dtype: int64], [array([0]), x    0
# Name: 110, dtype: int64], [array([0]), x    0
# Name: 111, dtype: int64], [array([0]), x    0
# Name: 112, dtype: int64], [array([0]), x    0
# Name: 113, dtype: int64], [array([0]), x    0
# Name: 114, dtype: int64], [array([0]), x    0
# Name: 115, dtype: int64], [array([0]), x    0
# Name: 116, dtype: int64], [array([0]), x    0
# Name: 117, dtype: int64], [array([0]), x    0
# Name: 118, dtype: int64], [array([0]), x    0
# Name: 119, dtype: int64], [array([0]), x    0
# Name: 120, dtype: int64], [array([0]), x    0
# Name: 121, dtype: int64], [array([0]), x    0
# Name: 122, dtype: int64], [array([0]), x    0
# Name: 123, dtype: int64], [array([0]), x    0
# Name: 124, dtype: int64], [array([0]), x    0
# Name: 125, dtype: int64], [array([0]), x    0
# Name: 126, dtype: int64], [array([0]), x    0
# Name: 127, dtype: int64], [array([0]), x    0
# Name: 128, dtype: int64], [array([0]), x    0
# Name: 129, dtype: int64], [array([0]), x    0
# Name: 130, dtype: int64], [array([0]), x    0
# Name: 131, dtype: int64], [array([0]), x    0
# Name: 132, dtype: int64], [array([0]), x    0
# Name: 133, dtype: int64], [array([0]), x    0
# Name: 134, dtype: int64], [array([0]), x    0
# Name: 135, dtype: int64], [array([0]), x    0
# Name: 136, dtype: int64], [array([0]), x    0
# Name: 137, dtype: int64], [array([0]), x    0
# Name: 138, dtype: int64], [array([0]), x    0
# Name: 139, dtype: int64], [array([0]), x    0
# Name: 140, dtype: int64], [array([0]), x    0
# Name: 141, dtype: int64], [array([0]), x    0
# Name: 142, dtype: int64], [array([0]), x    0
# Name: 143, dtype: int64], [array([0]), x    0
# Name: 144, dtype: int64], [array([0]), x    0
# Name: 145, dtype: int64], [array([0]), x    0
# Name: 146, dtype: int64], [array([0]), x    0
# Name: 147, dtype: int64], [array([0]), x    0
# Name: 148, dtype: int64], [array([0]), x    0
# Name: 149, dtype: int64], [array([0]), x    0
# Name: 150, dtype: int64], [array([0]), x    0
# Name: 151, dtype: int64], [array([0]), x    0
# Name: 152, dtype: int64], [array([0]), x    0
# Name: 153, dtype: int64], [array([0]), x    0
# Name: 154, dtype: int64], [array([0]), x    0
# Name: 155, dtype: int64], [array([0]), x    0
# Name: 156, dtype: int64], [array([0]), x    0
# Name: 157, dtype: int64], [array([0]), x    0
# Name: 158, dtype: int64], [array([0]), x    0
# Name: 159, dtype: int64], [array([0]), x    0
# Name: 160, dtype: int64], [array([0]), x    0
# Name: 161, dtype: int64], [array([0]), x    0
# Name: 162, dtype: int64], [array([0]), x    0
# Name: 163, dtype: int64], [array([0]), x    0
# Name: 164, dtype: int64], [array([0]), x    0
# Name: 165, dtype: int64], [array([0]), x    0
# Name: 166, dtype: int64], [array([0]), x    0
# Name: 167, dtype: int64], [array([0]), x    0
# Name: 168, dtype: int64], [array([0]), x    0
# Name: 169, dtype: int64], [array([0]), x    0
# Name: 170, dtype: int64], [array([0]), x    0
# Name: 171, dtype: int64], [array([0]), x    0
# Name: 172, dtype: int64], [array([0]), x    0
# Name: 173, dtype: int64], [array([0]), x    0
# Name: 174, dtype: int64], [array([0]), x    0
# Name: 175, dtype: int64], [array([0]), x    0
# Name: 176, dtype: int64], [array([0]), x    0
# Name: 177, dtype: int64], [array([0]), x    0
# Name: 178, dtype: int64], [array([0]), x    0
# Name: 179, dtype: int64], [array([0]), x    0
# Name: 180, dtype: int64], [array([0]), x    0
# Name: 181, dtype: int64], [array([0]), x    0
# Name: 182, dtype: int64], [array([0]), x    0
# Name: 183, dtype: int64], [array([0]), x    0
# Name: 184, dtype: int64], [array([0]), x    0
# Name: 185, dtype: int64], [array([0]), x    0
# Name: 186, dtype: int64], [array([0]), x    0
# Name: 187, dtype: int64], [array([0]), x    0
# Name: 188, dtype: int64], [array([0]), x    0
# Name: 189, dtype: int64], [array([0]), x    0
# Name: 190, dtype: int64], [array([0]), x    0
# Name: 191, dtype: int64], [array([0]), x    0
# Name: 192, dtype: int64], [array([1]), x    1
# Name: 193, dtype: int64], [array([1]), x    1
# Name: 194, dtype: int64], [array([0]), x    0
# Name: 195, dtype: int64], [array([0]), x    0
# Name: 196, dtype: int64], [array([0]), x    0
# Name: 197, dtype: int64], [array([0]), x    0
# Name: 198, dtype: int64], [array([0]), x    0
# Name: 199, dtype: int64], [array([0]), x    0
# Name: 200, dtype: int64], [array([0]), x    0
# Name: 201, dtype: int64], [array([0]), x    0
# Name: 202, dtype: int64], [array([1]), x    1
# Name: 203, dtype: int64], [array([1]), x    1
# Name: 204, dtype: int64], [array([1]), x    1
# Name: 205, dtype: int64], [array([1]), x    1
# Name: 206, dtype: int64], [array([1]), x    1
# Name: 207, dtype: int64], [array([1]), x    1
# Name: 208, dtype: int64], [array([1]), x    1
# Name: 209, dtype: int64], [array([1]), x    1
# Name: 210, dtype: int64], [array([1]), x    1
# Name: 211, dtype: int64], [array([1]), x    1
# Name: 212, dtype: int64], [array([0]), x    0
# Name: 213, dtype: int64], [array([0]), x    0
# Name: 214, dtype: int64], [array([0]), x    0
# Name: 215, dtype: int64], [array([0]), x    0
# Name: 216, dtype: int64], [array([0]), x    0
# Name: 217, dtype: int64], [array([1]), x    1
# Name: 218, dtype: int64], [array([0]), x    0
# Name: 219, dtype: int64], [array([0]), x    0
# Name: 220, dtype: int64], [array([0]), x    0
# Name: 221, dtype: int64], [array([0]), x    0
# Name: 222, dtype: int64], [array([0]), x    0
# Name: 223, dtype: int64], [array([0]), x    0
# Name: 224, dtype: int64], [array([0]), x    0
# Name: 225, dtype: int64], [array([0]), x    0
# Name: 226, dtype: int64], [array([0]), x    0
# Name: 227, dtype: int64], [array([0]), x    0
# Name: 228, dtype: int64], [array([0]), x    0
# Name: 229, dtype: int64], [array([0]), x    0
# Name: 230, dtype: int64], [array([0]), x    0
# Name: 231, dtype: int64], [array([0]), x    0
# Name: 232, dtype: int64], [array([0]), x    0
# Name: 233, dtype: int64], [array([0]), x    0
# Name: 234, dtype: int64], [array([0]), x    0
# Name: 235, dtype: int64], [array([0]), x    0
# Name: 236, dtype: int64], [array([0]), x    0
# Name: 237, dtype: int64], [array([0]), x    0
# Name: 238, dtype: int64], [array([0]), x    0
# Name: 239, dtype: int64], [array([0]), x    0
# Name: 240, dtype: int64], [array([0]), x    0
# Name: 241, dtype: int64], [array([0]), x    0
# Name: 242, dtype: int64], [array([0]), x    0
# Name: 243, dtype: int64], [array([0]), x    0
# Name: 244, dtype: int64], [array([0]), x    0
# Name: 245, dtype: int64], [array([0]), x    0
# Name: 246, dtype: int64], [array([0]), x    0
# Name: 247, dtype: int64], [array([0]), x    0
# Name: 248, dtype: int64], [array([0]), x    0
# Name: 249, dtype: int64], [array([0]), x    0
# Name: 250, dtype: int64], [array([0]), x    0
# Name: 251, dtype: int64], [array([0]), x    0
# Name: 252, dtype: int64], [array([0]), x    0
# Name: 253, dtype: int64], [array([0]), x    0
# Name: 254, dtype: int64], [array([0]), x    0
# Name: 255, dtype: int64], [array([0]), x    0
# Name: 256, dtype: int64], [array([0]), x    0
# Name: 257, dtype: int64], [array([0]), x    0
# Name: 258, dtype: int64], [array([0]), x    0
# Name: 259, dtype: int64], [array([0]), x    0
# Name: 260, dtype: int64], [array([0]), x    0
# Name: 261, dtype: int64], [array([0]), x    0
# Name: 262, dtype: int64], [array([0]), x    0
# Name: 263, dtype: int64], [array([0]), x    0
# Name: 264, dtype: int64], [array([0]), x    0
# Name: 265, dtype: int64], [array([0]), x    0
# Name: 266, dtype: int64], [array([0]), x    0
# Name: 267, dtype: int64], [array([0]), x    0
# Name: 268, dtype: int64], [array([0]), x    0
# Name: 269, dtype: int64], [array([0]), x    0
# Name: 270, dtype: int64], [array([0]), x    0
# Name: 271, dtype: int64], [array([0]), x    0
# Name: 272, dtype: int64], [array([0]), x    0
# Name: 273, dtype: int64], [array([0]), x    0
# Name: 274, dtype: int64], [array([0]), x    0
# Name: 275, dtype: int64], [array([0]), x    0
# Name: 276, dtype: int64], [array([0]), x    0
# Name: 277, dtype: int64], [array([0]), x    0
# Name: 278, dtype: int64], [array([0]), x    0
# Name: 279, dtype: int64], [array([0]), x    0
# Name: 280, dtype: int64], [array([0]), x    0
# Name: 281, dtype: int64], [array([0]), x    0
# Name: 282, dtype: int64], [array([0]), x    0
# Name: 283, dtype: int64], [array([0]), x    0
# Name: 284, dtype: int64], [array([0]), x    0
# Name: 285, dtype: int64], [array([0]), x    0
# Name: 286, dtype: int64], [array([0]), x    0
# Name: 287, dtype: int64], [array([0]), x    0
# Name: 288, dtype: int64], [array([1]), x    1
# Name: 289, dtype: int64], [array([1]), x    1
# Name: 290, dtype: int64], [array([0]), x    0
# Name: 291, dtype: int64], [array([0]), x    0
# Name: 292, dtype: int64], [array([0]), x    0
# Name: 293, dtype: int64], [array([0]), x    0
# Name: 294, dtype: int64], [array([0]), x    0
# Name: 295, dtype: int64], [array([0]), x    0
# Name: 296, dtype: int64], [array([0]), x    0
# Name: 297, dtype: int64], [array([0]), x    0
# Name: 298, dtype: int64], [array([0]), x    0
# Name: 299, dtype: int64], [array([0]), x    0
# Name: 300, dtype: int64], [array([0]), x    0
# Name: 301, dtype: int64], [array([0]), x    0
# Name: 302, dtype: int64], [array([0]), x    0
# Name: 303, dtype: int64], [array([0]), x    0
# Name: 304, dtype: int64], [array([0]), x    0
# Name: 305, dtype: int64], [array([0]), x    0
# Name: 306, dtype: int64], [array([0]), x    0
# Name: 307, dtype: int64], [array([0]), x    0
# Name: 308, dtype: int64], [array([0]), x    0
# Name: 309, dtype: int64], [array([0]), x    0
# Name: 310, dtype: int64], [array([0]), x    0
# Name: 311, dtype: int64], [array([0]), x    0
# Name: 312, dtype: int64], [array([0]), x    0
# Name: 313, dtype: int64], [array([0]), x    0
# Name: 314, dtype: int64], [array([0]), x    0
# Name: 315, dtype: int64], [array([0]), x    0
# Name: 316, dtype: int64], [array([0]), x    0
# Name: 317, dtype: int64], [array([0]), x    0
# Name: 318, dtype: int64], [array([0]), x    0
# Name: 319, dtype: int64], [array([0]), x    0
# Name: 320, dtype: int64], [array([0]), x    0
# Name: 321, dtype: int64], [array([0]), x    0
# Name: 322, dtype: int64], [array([0]), x    0
# Name: 323, dtype: int64], [array([0]), x    0
# Name: 324, dtype: int64], [array([0]), x    0
# Name: 325, dtype: int64], [array([0]), x    0
# Name: 326, dtype: int64], [array([0]), x    0
# Name: 327, dtype: int64], [array([0]), x    0
# Name: 328, dtype: int64], [array([1]), x    1
# Name: 329, dtype: int64], [array([1]), x    1
# Name: 330, dtype: int64], [array([1]), x    1
# Name: 331, dtype: int64], [array([0]), x    0
# Name: 332, dtype: int64], [array([0]), x    0
# Name: 333, dtype: int64], [array([1]), x    1
# Name: 334, dtype: int64], [array([1]), x    1
# Name: 335, dtype: int64], [array([1]), x    1
# Name: 336, dtype: int64], [array([1]), x    1
# Name: 337, dtype: int64], [array([1]), x    1
# Name: 338, dtype: int64], [array([1]), x    1
# Name: 339, dtype: int64], [array([0]), x    0
# Name: 340, dtype: int64], [array([0]), x    0
# Name: 341, dtype: int64], [array([0]), x    0
# Name: 342, dtype: int64], [array([0]), x    0
# Name: 343, dtype: int64], [array([0]), x    0
# Name: 344, dtype: int64], [array([1]), x    1
# Name: 345, dtype: int64], [array([0]), x    0
# Name: 346, dtype: int64], [array([0]), x    0
# Name: 347, dtype: int64], [array([0]), x    0
# Name: 348, dtype: int64], [array([0]), x    0
# Name: 349, dtype: int64], [array([0]), x    0
# Name: 350, dtype: int64], [array([0]), x    0
# Name: 351, dtype: int64], [array([0]), x    0
# Name: 352, dtype: int64], [array([0]), x    0
# Name: 353, dtype: int64], [array([0]), x    0
# Name: 354, dtype: int64], [array([0]), x    0
# Name: 355, dtype: int64], [array([0]), x    0
# Name: 356, dtype: int64], [array([0]), x    0
# Name: 357, dtype: int64], [array([0]), x    0
# Name: 358, dtype: int64], [array([0]), x    0
# Name: 359, dtype: int64], [array([0]), x    0
# Name: 360, dtype: int64], [array([0]), x    0
# Name: 361, dtype: int64], [array([0]), x    0
# Name: 362, dtype: int64], [array([0]), x    0
# Name: 363, dtype: int64], [array([0]), x    0
# Name: 364, dtype: int64], [array([0]), x    0
# Name: 365, dtype: int64], [array([0]), x    0
# Name: 366, dtype: int64], [array([0]), x    0
# Name: 367, dtype: int64], [array([0]), x    0
# Name: 368, dtype: int64], [array([1]), x    1
# Name: 369, dtype: int64], [array([1]), x    1
# Name: 370, dtype: int64], [array([0]), x    0
# Name: 371, dtype: int64], [array([0]), x    0
# Name: 372, dtype: int64], [array([0]), x    0
# Name: 373, dtype: int64], [array([0]), x    0
# Name: 374, dtype: int64], [array([0]), x    0
# Name: 375, dtype: int64], [array([0]), x    0
# Name: 376, dtype: int64], [array([0]), x    0
# Name: 377, dtype: int64], [array([0]), x    0
# Name: 378, dtype: int64], [array([0]), x    0
# Name: 379, dtype: int64], [array([0]), x    0
# Name: 380, dtype: int64], [array([0]), x    0
# Name: 381, dtype: int64], [array([0]), x    0
# Name: 382, dtype: int64], [array([0]), x    0
# Name: 383, dtype: int64], [array([0]), x    0
# Name: 384, dtype: int64], [array([0]), x    0
# Name: 385, dtype: int64], [array([0]), x    0
# Name: 386, dtype: int64], [array([0]), x    0
# Name: 387, dtype: int64], [array([0]), x    0
# Name: 388, dtype: int64], [array([0]), x    0
# Name: 389, dtype: int64], [array([0]), x    0
# Name: 390, dtype: int64], [array([0]), x    0
# Name: 391, dtype: int64], [array([0]), x    0
# Name: 392, dtype: int64], [array([0]), x    0
# Name: 393, dtype: int64], [array([0]), x    0
# Name: 394, dtype: int64], [array([0]), x    0
# Name: 395, dtype: int64], [array([0]), x    0
# Name: 396, dtype: int64], [array([0]), x    0
# Name: 397, dtype: int64], [array([0]), x    0
# Name: 398, dtype: int64], [array([0]), x    0
# Name: 399, dtype: int64], [array([0]), x    0
# Name: 400, dtype: int64], [array([0]), x    0
# Name: 401, dtype: int64], [array([0]), x    0
# Name: 402, dtype: int64], [array([0]), x    0
# Name: 403, dtype: int64], [array([0]), x    0
# Name: 404, dtype: int64], [array([0]), x    0
# Name: 405, dtype: int64], [array([0]), x    0
# Name: 406, dtype: int64], [array([0]), x    0
# Name: 407, dtype: int64], [array([0]), x    0
# Name: 408, dtype: int64], [array([0]), x    0
# Name: 409, dtype: int64], [array([0]), x    0
# Name: 410, dtype: int64], [array([0]), x    0
# Name: 411, dtype: int64], [array([0]), x    0
# Name: 412, dtype: int64], [array([0]), x    0
# Name: 413, dtype: int64], [array([0]), x    0
# Name: 414, dtype: int64], [array([0]), x    0
# Name: 415, dtype: int64], [array([1]), x    1
# Name: 416, dtype: int64], [array([0]), x    0
# Name: 417, dtype: int64], [array([0]), x    0
# Name: 418, dtype: int64], [array([0]), x    0
# Name: 419, dtype: int64], [array([0]), x    0
# Name: 420, dtype: int64], [array([1]), x    1
# Name: 421, dtype: int64], [array([0]), x    0
# Name: 422, dtype: int64], [array([1]), x    1
# Name: 423, dtype: int64], [array([0]), x    0
# Name: 424, dtype: int64], [array([0]), x    0
# Name: 425, dtype: int64], [array([0]), x    0
# Name: 426, dtype: int64], [array([0]), x    0
# Name: 427, dtype: int64], [array([0]), x    0
# Name: 428, dtype: int64], [array([1]), x    1
# Name: 429, dtype: int64], [array([0]), x    0
# Name: 430, dtype: int64], [array([0]), x    0
# Name: 431, dtype: int64], [array([0]), x    0
# Name: 432, dtype: int64], [array([0]), x    0
# Name: 433, dtype: int64], [array([0]), x    0
# Name: 434, dtype: int64], [array([0]), x    0
# Name: 435, dtype: int64], [array([0]), x    0
# Name: 436, dtype: int64], [array([0]), x    0
# Name: 437, dtype: int64], [array([0]), x    0
# Name: 438, dtype: int64], [array([0]), x    0
# Name: 439, dtype: int64], [array([0]), x    0
# Name: 440, dtype: int64], [array([0]), x    0
# Name: 441, dtype: int64], [array([0]), x    0
# Name: 442, dtype: int64], [array([0]), x    0
# Name: 443, dtype: int64], [array([0]), x    0
# Name: 444, dtype: int64], [array([0]), x    0
# Name: 445, dtype: int64], [array([0]), x    0
# Name: 446, dtype: int64], [array([0]), x    0
# Name: 447, dtype: int64], [array([0]), x    0
# Name: 448, dtype: int64], [array([0]), x    0
# Name: 449, dtype: int64], [array([0]), x    0
# Name: 450, dtype: int64], [array([0]), x    0
# Name: 451, dtype: int64], [array([0]), x    0
# Name: 452, dtype: int64], [array([0]), x    0
# Name: 453, dtype: int64], [array([0]), x    0
# Name: 454, dtype: int64], [array([1]), x    1
# Name: 455, dtype: int64], [array([1]), x    1
# Name: 456, dtype: int64], [array([0]), x    0
# Name: 457, dtype: int64], [array([0]), x    0
# Name: 458, dtype: int64], [array([0]), x    0
# Name: 459, dtype: int64], [array([0]), x    0
# Name: 460, dtype: int64], [array([0]), x    0
# Name: 461, dtype: int64], [array([0]), x    0
# Name: 462, dtype: int64], [array([0]), x    0
# Name: 463, dtype: int64], [array([0]), x    0
# Name: 464, dtype: int64], [array([0]), x    0
# Name: 465, dtype: int64], [array([0]), x    0
# Name: 466, dtype: int64], [array([0]), x    0
# Name: 467, dtype: int64], [array([0]), x    0
# Name: 468, dtype: int64], [array([0]), x    0
# Name: 469, dtype: int64], [array([0]), x    0
# Name: 470, dtype: int64], [array([0]), x    0
# Name: 471, dtype: int64], [array([0]), x    0
# Name: 472, dtype: int64], [array([0]), x    0
# Name: 473, dtype: int64], [array([0]), x    0
# Name: 474, dtype: int64], [array([0]), x    0
# Name: 475, dtype: int64], [array([0]), x    0
# Name: 476, dtype: int64], [array([0]), x    0
# Name: 477, dtype: int64], [array([0]), x    0
# Name: 478, dtype: int64], [array([0]), x    0
# Name: 479, dtype: int64], [array([0]), x    0
# Name: 480, dtype: int64], [array([0]), x    0
# Name: 481, dtype: int64], [array([0]), x    0
# Name: 482, dtype: int64], [array([0]), x    0
# Name: 483, dtype: int64], [array([0]), x    0
# Name: 484, dtype: int64], [array([0]), x    0
# Name: 485, dtype: int64], [array([1]), x    1
# Name: 486, dtype: int64], [array([1]), x    1
# Name: 487, dtype: int64], [array([1]), x    1
# Name: 488, dtype: int64], [array([1]), x    1
# Name: 489, dtype: int64], [array([1]), x    1
# Name: 490, dtype: int64], [array([1]), x    1
# Name: 491, dtype: int64], [array([1]), x    1
# Name: 492, dtype: int64], [array([1]), x    1
# Name: 493, dtype: int64], [array([1]), x    1
# Name: 494, dtype: int64], [array([1]), x    1
# Name: 495, dtype: int64], [array([1]), x    1
# Name: 496, dtype: int64], [array([1]), x    1
# Name: 497, dtype: int64], [array([1]), x    1
# Name: 498, dtype: int64], [array([1]), x    1
# Name: 499, dtype: int64], [array([1]), x    1
# Name: 500, dtype: int64], [array([1]), x    1
# Name: 501, dtype: int64], [array([1]), x    1
# Name: 502, dtype: int64], [array([0]), x    0
# Name: 503, dtype: int64], [array([1]), x    1
# Name: 504, dtype: int64], [array([1]), x    1
# Name: 505, dtype: int64], [array([1]), x    1
# Name: 506, dtype: int64], [array([1]), x    1
# Name: 507, dtype: int64], [array([1]), x    1
# Name: 508, dtype: int64], [array([1]), x    1
# Name: 509, dtype: int64], [array([1]), x    1
# Name: 510, dtype: int64], [array([1]), x    1
# Name: 511, dtype: int64], [array([1]), x    1
# Name: 512, dtype: int64], [array([1]), x    1
# Name: 513, dtype: int64], [array([1]), x    1
# Name: 514, dtype: int64], [array([1]), x    1
# Name: 515, dtype: int64], [array([1]), x    1
# Name: 516, dtype: int64], [array([0]), x    0
# Name: 517, dtype: int64], [array([0]), x    0
# Name: 518, dtype: int64], [array([0]), x    0
# Name: 519, dtype: int64], [array([0]), x    0
# Name: 520, dtype: int64], [array([0]), x    0
# Name: 521, dtype: int64], [array([0]), x    0
# Name: 522, dtype: int64], [array([0]), x    0
# Name: 523, dtype: int64], [array([0]), x    0
# Name: 524, dtype: int64], [array([0]), x    0
# Name: 525, dtype: int64], [array([0]), x    0
# Name: 526, dtype: int64], [array([0]), x    0
# Name: 527, dtype: int64], [array([0]), x    0
# Name: 528, dtype: int64], [array([0]), x    0
# Name: 529, dtype: int64], [array([0]), x    0
# Name: 530, dtype: int64], [array([0]), x    0
# Name: 531, dtype: int64], [array([0]), x    0
# Name: 532, dtype: int64], [array([0]), x    0
# Name: 533, dtype: int64], [array([0]), x    0
# Name: 534, dtype: int64], [array([0]), x    0
# Name: 535, dtype: int64], [array([0]), x    0
# Name: 536, dtype: int64], [array([0]), x    0
# Name: 537, dtype: int64], [array([0]), x    0
# Name: 538, dtype: int64], [array([0]), x    0
# Name: 539, dtype: int64], [array([0]), x    0
# Name: 540, dtype: int64], [array([0]), x    0
# Name: 541, dtype: int64], [array([0]), x    0
# Name: 542, dtype: int64], [array([0]), x    0
# Name: 543, dtype: int64], [array([0]), x    0
# Name: 544, dtype: int64], [array([0]), x    0
# Name: 545, dtype: int64], [array([0]), x    0
# Name: 546, dtype: int64], [array([1]), x    1
# Name: 547, dtype: int64], [array([1]), x    1
# Name: 548, dtype: int64], [array([1]), x    1
# Name: 549, dtype: int64], [array([1]), x    1
# Name: 550, dtype: int64], [array([1]), x    1
# Name: 551, dtype: int64], [array([1]), x    1
# Name: 552, dtype: int64], [array([1]), x    1
# Name: 553, dtype: int64], [array([1]), x    1
# Name: 554, dtype: int64], [array([1]), x    1
# Name: 555, dtype: int64], [array([1]), x    1
# Name: 556, dtype: int64], [array([0]), x    0
# Name: 557, dtype: int64], [array([1]), x    1
# Name: 558, dtype: int64], [array([1]), x    1
# Name: 559, dtype: int64], [array([1]), x    1
# Name: 560, dtype: int64], [array([1]), x    1
# Name: 561, dtype: int64], [array([1]), x    1
# Name: 562, dtype: int64], [array([1]), x    1
# Name: 563, dtype: int64], [array([1]), x    1
# Name: 564, dtype: int64], [array([1]), x    1
# Name: 565, dtype: int64], [array([1]), x    1
# Name: 566, dtype: int64], [array([1]), x    1
# Name: 567, dtype: int64], [array([1]), x    1
# Name: 568, dtype: int64], [array([1]), x    1
# Name: 569, dtype: int64], [array([1]), x    1
# Name: 570, dtype: int64], [array([1]), x    1
# Name: 571, dtype: int64], [array([1]), x    1
# Name: 572, dtype: int64], [array([1]), x    1
# Name: 573, dtype: int64], [array([1]), x    1
# Name: 574, dtype: int64], [array([1]), x    1
# Name: 575, dtype: int64], [array([1]), x    1
# Name: 576, dtype: int64], [array([1]), x    1
# Name: 577, dtype: int64], [array([1]), x    1
# Name: 578, dtype: int64], [array([1]), x    1
# Name: 579, dtype: int64], [array([1]), x    1
# Name: 580, dtype: int64], [array([1]), x    1
# Name: 581, dtype: int64], [array([1]), x    1
# Name: 582, dtype: int64], [array([1]), x    1
# Name: 583, dtype: int64], [array([1]), x    1
# Name: 584, dtype: int64], [array([1]), x    1
# Name: 585, dtype: int64], [array([1]), x    1
# Name: 586, dtype: int64], [array([1]), x    1
# Name: 587, dtype: int64], [array([1]), x    1
# Name: 588, dtype: int64], [array([1]), x    1
# Name: 589, dtype: int64], [array([1]), x    1
# Name: 590, dtype: int64], [array([1]), x    1
# Name: 591, dtype: int64], [array([1]), x    1
# Name: 592, dtype: int64], [array([1]), x    1
# Name: 593, dtype: int64], [array([1]), x    1
# Name: 594, dtype: int64], [array([1]), x    1
# Name: 595, dtype: int64], [array([1]), x    1
# Name: 596, dtype: int64], [array([0]), x    0
# Name: 597, dtype: int64], [array([0]), x    0
# Name: 598, dtype: int64], [array([1]), x    1
# Name: 599, dtype: int64], [array([1]), x    1
# Name: 600, dtype: int64], [array([1]), x    1
# Name: 601, dtype: int64], [array([1]), x    1
# Name: 602, dtype: int64], [array([1]), x    1
# Name: 603, dtype: int64], [array([1]), x    1
# Name: 604, dtype: int64], [array([1]), x    1
# Name: 605, dtype: int64], [array([1]), x    1
# Name: 606, dtype: int64], [array([1]), x    1
# Name: 607, dtype: int64], [array([0]), x    0
# Name: 608, dtype: int64], [array([0]), x    0
# Name: 609, dtype: int64], [array([0]), x    0
# Name: 610, dtype: int64], [array([0]), x    0
# Name: 611, dtype: int64], [array([0]), x    0
# Name: 612, dtype: int64], [array([0]), x    0
# Name: 613, dtype: int64], [array([0]), x    0
# Name: 614, dtype: int64], [array([0]), x    0
# Name: 615, dtype: int64], [array([0]), x    0
# Name: 616, dtype: int64], [array([1]), x    1
# Name: 617, dtype: int64], [array([1]), x    1
# Name: 618, dtype: int64], [array([1]), x    1
# Name: 619, dtype: int64], [array([1]), x    1
# Name: 620, dtype: int64], [array([1]), x    1
# Name: 621, dtype: int64], [array([1]), x    1
# Name: 622, dtype: int64], [array([1]), x    1
# Name: 623, dtype: int64], [array([1]), x    1
# Name: 624, dtype: int64], [array([1]), x    1
# Name: 625, dtype: int64], [array([1]), x    1
# Name: 626, dtype: int64], [array([1]), x    1
# Name: 627, dtype: int64], [array([1]), x    1
# Name: 628, dtype: int64], [array([1]), x    1
# Name: 629, dtype: int64], [array([0]), x    0
# Name: 630, dtype: int64], [array([1]), x    1
# Name: 631, dtype: int64], [array([0]), x    0
# Name: 632, dtype: int64], [array([0]), x    0
# Name: 633, dtype: int64], [array([1]), x    1
# Name: 634, dtype: int64], [array([1]), x    1
# Name: 635, dtype: int64], [array([1]), x    1
# Name: 636, dtype: int64], [array([1]), x    1
# Name: 637, dtype: int64], [array([1]), x    1
# Name: 638, dtype: int64], [array([1]), x    1
# Name: 639, dtype: int64], [array([1]), x    1
# Name: 640, dtype: int64], [array([1]), x    1
# Name: 641, dtype: int64], [array([1]), x    1
# Name: 642, dtype: int64], [array([1]), x    1
# Name: 643, dtype: int64], [array([1]), x    1
# Name: 644, dtype: int64], [array([1]), x    1
# Name: 645, dtype: int64], [array([1]), x    1
# Name: 646, dtype: int64], [array([0]), x    0
# Name: 647, dtype: int64], [array([0]), x    0
# Name: 648, dtype: int64], [array([1]), x    1
# Name: 649, dtype: int64], [array([0]), x    0
# Name: 650, dtype: int64], [array([0]), x    0
# Name: 651, dtype: int64], [array([0]), x    0
# Name: 652, dtype: int64], [array([0]), x    0
# Name: 653, dtype: int64], [array([0]), x    0
# Name: 654, dtype: int64], [array([0]), x    0
# Name: 655, dtype: int64], [array([0]), x    0
# Name: 656, dtype: int64], [array([0]), x    0
# Name: 657, dtype: int64], [array([0]), x    0
# Name: 658, dtype: int64], [array([0]), x    0
# Name: 659, dtype: int64], [array([1]), x    1
# Name: 660, dtype: int64], [array([1]), x    1
# Name: 661, dtype: int64], [array([1]), x    1
# Name: 662, dtype: int64], [array([0]), x    0
# Name: 663, dtype: int64], [array([1]), x    1
# Name: 664, dtype: int64], [array([1]), x    1
# Name: 665, dtype: int64], [array([1]), x    1
# Name: 666, dtype: int64], [array([1]), x    1
# Name: 667, dtype: int64], [array([1]), x    1
# Name: 668, dtype: int64], [array([1]), x    1
# Name: 669, dtype: int64], [array([1]), x    1
# Name: 670, dtype: int64], [array([1]), x    1
# Name: 671, dtype: int64], [array([1]), x    1
# Name: 672, dtype: int64], [array([1]), x    1
# Name: 673, dtype: int64], [array([1]), x    1
# Name: 674, dtype: int64], [array([1]), x    1
# Name: 675, dtype: int64], [array([1]), x    1
# Name: 676, dtype: int64], [array([1]), x    1
# Name: 677, dtype: int64], [array([1]), x    1
# Name: 678, dtype: int64], [array([0]), x    0
# Name: 679, dtype: int64], [array([0]), x    0
# Name: 680, dtype: int64], [array([0]), x    0
# Name: 681, dtype: int64], [array([0]), x    0
# Name: 682, dtype: int64], [array([0]), x    0
# Name: 683, dtype: int64], [array([1]), x    1
# Name: 684, dtype: int64], [array([1]), x    1
# Name: 685, dtype: int64], [array([0]), x    0
# Name: 686, dtype: int64], [array([0]), x    0
# Name: 687, dtype: int64], [array([0]), x    0
# Name: 688, dtype: int64], [array([0]), x    0
# Name: 689, dtype: int64], [array([0]), x    0
# Name: 690, dtype: int64], [array([0]), x    0
# Name: 691, dtype: int64], [array([1]), x    1
# Name: 692, dtype: int64], [array([0]), x    0
# Name: 693, dtype: int64], [array([0]), x    0
# Name: 694, dtype: int64], [array([1]), x    1
# Name: 695, dtype: int64], [array([1]), x    1
# Name: 696, dtype: int64], [array([0]), x    0
# Name: 697, dtype: int64], [array([1]), x    1
# Name: 698, dtype: int64], [array([0]), x    0
# Name: 699, dtype: int64], [array([1]), x    1
# Name: 700, dtype: int64], [array([1]), x    1
# Name: 701, dtype: int64], [array([1]), x    1
# Name: 702, dtype: int64], [array([1]), x    1
# Name: 703, dtype: int64], [array([1]), x    1
# Name: 704, dtype: int64], [array([1]), x    1
# Name: 705, dtype: int64], [array([1]), x    1
# Name: 706, dtype: int64], [array([1]), x    1
# Name: 707, dtype: int64], [array([1]), x    1
# Name: 708, dtype: int64], [array([0]), x    0
# Name: 709, dtype: int64], [array([0]), x    0
# Name: 710, dtype: int64], [array([0]), x    0
# Name: 711, dtype: int64], [array([0]), x    0
# Name: 712, dtype: int64], [array([0]), x    0
# Name: 713, dtype: int64], [array([0]), x    0
# Name: 714, dtype: int64], [array([0]), x    0
# Name: 715, dtype: int64], [array([0]), x    0
# Name: 716, dtype: int64], [array([0]), x    0
# Name: 717, dtype: int64], [array([0]), x    0
# Name: 718, dtype: int64], [array([1]), x    1
# Name: 719, dtype: int64], [array([1]), x    1
# Name: 720, dtype: int64], [array([1]), x    1
# Name: 721, dtype: int64], [array([0]), x    0
# Name: 722, dtype: int64], [array([1]), x    1
# Name: 723, dtype: int64], [array([1]), x    1
# Name: 724, dtype: int64], [array([1]), x    1
# Name: 725, dtype: int64], [array([1]), x    1
# Name: 726, dtype: int64], [array([1]), x    1
# Name: 727, dtype: int64], [array([1]), x    1
# Name: 728, dtype: int64], [array([1]), x    1
# Name: 729, dtype: int64], [array([1]), x    1
# Name: 730, dtype: int64], [array([1]), x    1
# Name: 731, dtype: int64], [array([0]), x    0
# Name: 732, dtype: int64], [array([0]), x    0
# Name: 733, dtype: int64], [array([1]), x    1
# Name: 734, dtype: int64], [array([1]), x    1
# Name: 735, dtype: int64], [array([0]), x    0
# Name: 736, dtype: int64], [array([1]), x    1
# Name: 737, dtype: int64], [array([0]), x    0
# Name: 738, dtype: int64], [array([1]), x    1
# Name: 739, dtype: int64], [array([0]), x    0
# Name: 740, dtype: int64], [array([0]), x    0
# Name: 741, dtype: int64], [array([0]), x    0
# Name: 742, dtype: int64], [array([0]), x    0
# Name: 743, dtype: int64], [array([0]), x    0
# Name: 744, dtype: int64], [array([0]), x    0
# Name: 745, dtype: int64], [array([0]), x    0
# Name: 746, dtype: int64], [array([0]), x    0
# Name: 747, dtype: int64], [array([0]), x    0
# Name: 748, dtype: int64], [array([0]), x    0
# Name: 749, dtype: int64], [array([0]), x    0
# Name: 750, dtype: int64], [array([0]), x    0
# Name: 751, dtype: int64], [array([0]), x    0
# Name: 752, dtype: int64], [array([0]), x    0
# Name: 753, dtype: int64], [array([0]), x    0
# Name: 754, dtype: int64], [array([0]), x    0
# Name: 755, dtype: int64], [array([1]), x    1
# Name: 756, dtype: int64], [array([1]), x    1
# Name: 757, dtype: int64], [array([1]), x    1
# Name: 758, dtype: int64], [array([1]), x    1
# Name: 759, dtype: int64], [array([1]), x    1
# Name: 760, dtype: int64], [array([1]), x    1
# Name: 761, dtype: int64], [array([1]), x    1
# Name: 762, dtype: int64], [array([1]), x    1
# Name: 763, dtype: int64], [array([1]), x    1
# Name: 764, dtype: int64], [array([1]), x    1
# Name: 765, dtype: int64], [array([1]), x    1
# Name: 766, dtype: int64], [array([1]), x    1
# Name: 767, dtype: int64], [array([1]), x    1
# Name: 768, dtype: int64], [array([1]), x    1
# Name: 769, dtype: int64], [array([1]), x    1
# Name: 770, dtype: int64], [array([1]), x    1
# Name: 771, dtype: int64], [array([1]), x    1
# Name: 772, dtype: int64], [array([1]), x    1
# Name: 773, dtype: int64], [array([1]), x    1
# Name: 774, dtype: int64], [array([1]), x    1
# Name: 775, dtype: int64], [array([1]), x    1
# Name: 776, dtype: int64], [array([1]), x    1
# Name: 777, dtype: int64], [array([1]), x    1
# Name: 778, dtype: int64], [array([1]), x    1
# Name: 779, dtype: int64], [array([1]), x    1
# Name: 780, dtype: int64], [array([1]), x    1
# Name: 781, dtype: int64], [array([1]), x    1
# Name: 782, dtype: int64], [array([1]), x    1
# Name: 783, dtype: int64], [array([0]), x    0
# Name: 784, dtype: int64], [array([0]), x    0
# Name: 785, dtype: int64], [array([0]), x    0
# Name: 786, dtype: int64], [array([0]), x    0
# Name: 787, dtype: int64], [array([0]), x    0
# Name: 788, dtype: int64], [array([0]), x    0
# Name: 789, dtype: int64], [array([0]), x    0
# Name: 790, dtype: int64], [array([0]), x    0
# Name: 791, dtype: int64], [array([0]), x    0
# Name: 792, dtype: int64], [array([0]), x    0
# Name: 793, dtype: int64], [array([0]), x    0
# Name: 794, dtype: int64], [array([0]), x    0
# Name: 795, dtype: int64], [array([0]), x    0
# Name: 796, dtype: int64], [array([0]), x    0
# Name: 797, dtype: int64], [array([0]), x    0
# Name: 798, dtype: int64], [array([0]), x    0
# Name: 799, dtype: int64], [array([0]), x    0
# Name: 800, dtype: int64], [array([0]), x    0
# Name: 801, dtype: int64], [array([0]), x    0
# Name: 802, dtype: int64], [array([0]), x    0
# Name: 803, dtype: int64], [array([0]), x    0
# Name: 804, dtype: int64], [array([0]), x    0
# Name: 805, dtype: int64], [array([0]), x    0
# Name: 806, dtype: int64], [array([0]), x    0
# Name: 807, dtype: int64], [array([0]), x    0
# Name: 808, dtype: int64], [array([0]), x    0
# Name: 809, dtype: int64], [array([1]), x    1
# Name: 810, dtype: int64], [array([1]), x    1
# Name: 811, dtype: int64], [array([1]), x    1
# Name: 812, dtype: int64], [array([1]), x    1
# Name: 813, dtype: int64], [array([1]), x    1
# Name: 814, dtype: int64], [array([1]), x    1
# Name: 815, dtype: int64], [array([0]), x    0
# Name: 816, dtype: int64], [array([1]), x    1
# Name: 817, dtype: int64], [array([1]), x    1
# Name: 818, dtype: int64], [array([1]), x    1
# Name: 819, dtype: int64], [array([0]), x    0
# Name: 820, dtype: int64], [array([1]), x    1
# Name: 821, dtype: int64], [array([1]), x    1
# Name: 822, dtype: int64], [array([1]), x    1
# Name: 823, dtype: int64], [array([1]), x    1
# Name: 824, dtype: int64], [array([1]), x    1
# Name: 825, dtype: int64], [array([1]), x    1
# Name: 826, dtype: int64], [array([1]), x    1
# Name: 827, dtype: int64], [array([1]), x    1
# Name: 828, dtype: int64], [array([0]), x    0
# Name: 829, dtype: int64], [array([1]), x    1
# Name: 830, dtype: int64], [array([1]), x    1
# Name: 831, dtype: int64], [array([0]), x    0
# Name: 832, dtype: int64], [array([1]), x    1
# Name: 833, dtype: int64], [array([0]), x    0
# Name: 834, dtype: int64], [array([0]), x    0
# Name: 835, dtype: int64], [array([0]), x    0
# Name: 836, dtype: int64], [array([0]), x    0
# Name: 837, dtype: int64], [array([0]), x    0
# Name: 838, dtype: int64], [array([0]), x    0
# Name: 839, dtype: int64], [array([0]), x    0
# Name: 840, dtype: int64], [array([0]), x    0
# Name: 841, dtype: int64], [array([0]), x    0
# Name: 842, dtype: int64], [array([0]), x    0
# Name: 843, dtype: int64], [array([0]), x    0
# Name: 844, dtype: int64], [array([0]), x    0
# Name: 845, dtype: int64], [array([0]), x    0
# Name: 846, dtype: int64], [array([0]), x    0
# Name: 847, dtype: int64], [array([0]), x    0
# Name: 848, dtype: int64], [array([0]), x    0
# Name: 849, dtype: int64], [array([0]), x    0
# Name: 850, dtype: int64], [array([0]), x    0
# Name: 851, dtype: int64], [array([0]), x    0
# Name: 852, dtype: int64], [array([0]), x    0
# Name: 853, dtype: int64], [array([0]), x    0
# Name: 854, dtype: int64], [array([0]), x    0
# Name: 855, dtype: int64], [array([0]), x    0
# Name: 856, dtype: int64], [array([0]), x    0
# Name: 857, dtype: int64], [array([0]), x    0
# Name: 858, dtype: int64], [array([0]), x    0
# Name: 859, dtype: int64], [array([0]), x    0
# Name: 860, dtype: int64], [array([0]), x    0
# Name: 861, dtype: int64], [array([1]), x    1
# Name: 862, dtype: int64], [array([1]), x    1
# Name: 863, dtype: int64], [array([1]), x    1
# Name: 864, dtype: int64], [array([1]), x    1
# Name: 865, dtype: int64], [array([1]), x    1
# Name: 866, dtype: int64], [array([1]), x    1
# Name: 867, dtype: int64], [array([1]), x    1
# Name: 868, dtype: int64], [array([1]), x    1
# Name: 869, dtype: int64], [array([1]), x    1
# Name: 870, dtype: int64], [array([1]), x    1
# Name: 871, dtype: int64], [array([1]), x    1
# Name: 872, dtype: int64], [array([1]), x    1
# Name: 873, dtype: int64], [array([1]), x    1
# Name: 874, dtype: int64], [array([1]), x    1
# Name: 875, dtype: int64], [array([1]), x    1
# Name: 876, dtype: int64], [array([1]), x    1
# Name: 877, dtype: int64], [array([1]), x    1
# Name: 878, dtype: int64], [array([1]), x    1
# Name: 879, dtype: int64], [array([1]), x    1
# Name: 880, dtype: int64], [array([0]), x    0
# Name: 881, dtype: int64], [array([0]), x    0
# Name: 882, dtype: int64], [array([0]), x    0
# Name: 883, dtype: int64], [array([0]), x    0
# Name: 884, dtype: int64], [array([0]), x    0
# Name: 885, dtype: int64], [array([0]), x    0
# Name: 886, dtype: int64], [array([0]), x    0
# Name: 887, dtype: int64], [array([0]), x    0
# Name: 888, dtype: int64], [array([0]), x    0
# Name: 889, dtype: int64], [array([1]), x    1
# Name: 890, dtype: int64], [array([1]), x    1
# Name: 891, dtype: int64], [array([1]), x    1
# Name: 892, dtype: int64], [array([1]), x    1
# Name: 893, dtype: int64], [array([1]), x    1
# Name: 894, dtype: int64], [array([1]), x    1
# Name: 895, dtype: int64], [array([1]), x    1
# Name: 896, dtype: int64], [array([1]), x    1
# Name: 897, dtype: int64], [array([0]), x    0
# Name: 898, dtype: int64], [array([0]), x    0
# Name: 899, dtype: int64], [array([0]), x    0
# Name: 900, dtype: int64], [array([0]), x    0
# Name: 901, dtype: int64], [array([0]), x    0
# Name: 902, dtype: int64], [array([0]), x    0
# Name: 903, dtype: int64], [array([0]), x    0
# Name: 904, dtype: int64], [array([0]), x    0
# Name: 905, dtype: int64], [array([0]), x    0
# Name: 906, dtype: int64], [array([0]), x    0
# Name: 907, dtype: int64], [array([0]), x    0
# Name: 908, dtype: int64], [array([0]), x    0
# Name: 909, dtype: int64], [array([0]), x    0
# Name: 910, dtype: int64], [array([0]), x    0
# Name: 911, dtype: int64], [array([1]), x    1
# Name: 912, dtype: int64], [array([0]), x    0
# Name: 913, dtype: int64], [array([1]), x    1
# Name: 914, dtype: int64], [array([1]), x    1
# Name: 915, dtype: int64], [array([0]), x    0
# Name: 916, dtype: int64], [array([1]), x    1
# Name: 917, dtype: int64], [array([1]), x    1
# Name: 918, dtype: int64], [array([1]), x    1
# Name: 919, dtype: int64], [array([0]), x    0
# Name: 920, dtype: int64], [array([0]), x    0
# Name: 921, dtype: int64], [array([0]), x    0
# Name: 922, dtype: int64], [array([0]), x    0
# Name: 923, dtype: int64], [array([0]), x    0
# Name: 924, dtype: int64], [array([0]), x    0
# Name: 925, dtype: int64], [array([0]), x    0
# Name: 926, dtype: int64], [array([1]), x    1
# Name: 927, dtype: int64], [array([1]), x    1
# Name: 928, dtype: int64], [array([1]), x    1
# Name: 929, dtype: int64], [array([1]), x    1
# Name: 930, dtype: int64], [array([1]), x    1
# Name: 931, dtype: int64], [array([1]), x    1
# Name: 932, dtype: int64], [array([1]), x    1
# Name: 933, dtype: int64], [array([1]), x    1
# Name: 934, dtype: int64], [array([1]), x    1
# Name: 935, dtype: int64], [array([1]), x    1
# Name: 936, dtype: int64], [array([1]), x    1
# Name: 937, dtype: int64], [array([1]), x    1
# Name: 938, dtype: int64], [array([1]), x    1
# Name: 939, dtype: int64], [array([1]), x    1
# Name: 940, dtype: int64], [array([1]), x    1
# Name: 941, dtype: int64], [array([1]), x    1
# Name: 942, dtype: int64], [array([1]), x    1
# Name: 943, dtype: int64], [array([1]), x    1
# Name: 944, dtype: int64], [array([1]), x    1
# Name: 945, dtype: int64], [array([1]), x    1
# Name: 946, dtype: int64], [array([1]), x    1
# Name: 947, dtype: int64], [array([1]), x    1
# Name: 948, dtype: int64], [array([1]), x    1
# Name: 949, dtype: int64], [array([1]), x    1
# Name: 950, dtype: int64], [array([1]), x    1
# Name: 951, dtype: int64], [array([1]), x    1
# Name: 952, dtype: int64], [array([1]), x    1
# Name: 953, dtype: int64], [array([1]), x    1
# Name: 954, dtype: int64], [array([1]), x    1
# Name: 955, dtype: int64], [array([0]), x    0
# Name: 956, dtype: int64], [array([0]), x    0
# Name: 957, dtype: int64], [array([0]), x    0
# Name: 958, dtype: int64], [array([0]), x    0
# Name: 959, dtype: int64], [array([0]), x    0
# Name: 960, dtype: int64], [array([0]), x    0
# Name: 961, dtype: int64], [array([0]), x    0
# Name: 962, dtype: int64], [array([0]), x    0
# Name: 963, dtype: int64], [array([0]), x    0
# Name: 964, dtype: int64], [array([0]), x    0
# Name: 965, dtype: int64], [array([1]), x    1
# Name: 966, dtype: int64], [array([0]), x    0
# Name: 967, dtype: int64], [array([1]), x    1
# Name: 968, dtype: int64], [array([0]), x    0
# Name: 969, dtype: int64], [array([0]), x    0
# Name: 970, dtype: int64], [array([0]), x    0
# Name: 971, dtype: int64], [array([0]), x    0
# Name: 972, dtype: int64], [array([0]), x    0
# Name: 973, dtype: int64], [array([0]), x    0
# Name: 974, dtype: int64], [array([0]), x    0
# Name: 975, dtype: int64], [array([1]), x    1
# Name: 976, dtype: int64], [array([1]), x    1
# Name: 977, dtype: int64], [array([0]), x    0
# Name: 978, dtype: int64], [array([0]), x    0
# Name: 979, dtype: int64], [array([1]), x    1
# Name: 980, dtype: int64], [array([1]), x    1
# Name: 981, dtype: int64], [array([1]), x    1
# Name: 982, dtype: int64], [array([0]), x    0
# Name: 983, dtype: int64], [array([1]), x    1
# Name: 984, dtype: int64], [array([0]), x    0
# Name: 985, dtype: int64], [array([1]), x    1
# Name: 986, dtype: int64], [array([1]), x    1
# Name: 987, dtype: int64], [array([1]), x    1
# Name: 988, dtype: int64], [array([0]), x    0
# Name: 989, dtype: int64], [array([1]), x    1
# Name: 990, dtype: int64], [array([0]), x    0
# Name: 991, dtype: int64], [array([0]), x    0
# Name: 992, dtype: int64], [array([1]), x    1
# Name: 993, dtype: int64], [array([1]), x    1
# Name: 994, dtype: int64], [array([1]), x    1
# Name: 995, dtype: int64], [array([1]), x    1
# Name: 996, dtype: int64], [array([1]), x    1
# Name: 997, dtype: int64], [array([1]), x    1
# Name: 998, dtype: int64], [array([1]), x    1
# Name: 999, dtype: int64], [array([1]), x    1
# Name: 1000, dtype: int64], [array([1]), x    1
# Name: 1001, dtype: int64], [array([1]), x    1
# Name: 1002, dtype: int64], [array([1]), x    1
# Name: 1003, dtype: int64], [array([0]), x    0
# Name: 1004, dtype: int64], [array([0]), x    0
# Name: 1005, dtype: int64], [array([0]), x    0
# Name: 1006, dtype: int64], [array([0]), x    0
# Name: 1007, dtype: int64], [array([0]), x    0
# Name: 1008, dtype: int64], [array([0]), x    0
# Name: 1009, dtype: int64], [array([0]), x    0
# Name: 1010, dtype: int64], [array([1]), x    1
# Name: 1011, dtype: int64], [array([1]), x    1
# Name: 1012, dtype: int64], [array([1]), x    1
# Name: 1013, dtype: int64], [array([1]), x    1
# Name: 1014, dtype: int64], [array([1]), x    1
# Name: 1015, dtype: int64], [array([0]), x    0
# Name: 1016, dtype: int64], [array([0]), x    0
# Name: 1017, dtype: int64], [array([0]), x    0
# Name: 1018, dtype: int64], [array([0]), x    0
# Name: 1019, dtype: int64], [array([0]), x    0
# Name: 1020, dtype: int64], [array([0]), x    0
# Name: 1021, dtype: int64], [array([0]), x    0
# Name: 1022, dtype: int64], [array([0]), x    0
# Name: 1023, dtype: int64], [array([0]), x    0
# Name: 1024, dtype: int64], [array([0]), x    0
# Name: 1025, dtype: int64], [array([0]), x    0
# Name: 1026, dtype: int64], [array([0]), x    0
# Name: 1027, dtype: int64], [array([0]), x    0
# Name: 1028, dtype: int64], [array([0]), x    0
# Name: 1029, dtype: int64], [array([1]), x    1
# Name: 1030, dtype: int64], [array([1]), x    1
# Name: 1031, dtype: int64], [array([1]), x    1
# Name: 1032, dtype: int64], [array([1]), x    1
# Name: 1033, dtype: int64], [array([1]), x    1
# Name: 1034, dtype: int64], [array([1]), x    1
# Name: 1035, dtype: int64], [array([1]), x    1
# Name: 1036, dtype: int64], [array([1]), x    1
# Name: 1037, dtype: int64], [array([1]), x    1
# Name: 1038, dtype: int64], [array([1]), x    1
# Name: 1039, dtype: int64], [array([1]), x    1
# Name: 1040, dtype: int64], [array([1]), x    1
# Name: 1041, dtype: int64], [array([1]), x    1
# Name: 1042, dtype: int64], [array([1]), x    1
# Name: 1043, dtype: int64], [array([1]), x    1
# ...
# Name: 44477, dtype: int64], [array([0]), x    0
# Name: 44478, dtype: int64], [array([0]), x    0
# Name: 44479, dtype: int64], [array([0]), x    0
# Name: 44480, dtype: int64], [array([0]), x    0
# Name: 44481, dtype: int64], [array([0]), x    0
# Name: 44482, dtype: int64], [array([0]), x    0
# Name: 44483, dtype: int64], [array([0]), x    0
# Name: 44484, dtype: int64], [array([0]), x    0
# Name: 44485, dtype: int64], [array([0]), x    0
# Name: 44486, dtype: int64], [array([0]), x    0
# Name: 44487, dtype: int64], [array([0]), x    0
# Name: 44488, dtype: int64], [array([0]), x    0
# Name: 44489, dtype: int64], [array([0]), x    0
# Name: 44490, dtype: int64], [array([0]), x    0
# Name: 44491, dtype: int64], [array([0]), x    0
# Name: 44492, dtype: int64], [array([0]), x    0
# Name: 44493, dtype: int64], [array([0]), x    0
# Name: 44494, dtype: int64], [array([0]), x    0
# Name: 44495, dtype: int64], [array([0]), x    0
# Name: 44496, dtype: int64], [array([0]), x    0
# Name: 44497, dtype: int64], [array([0]), x    0
# Name: 44498, dtype: int64], [array([1]), x    1
# Name: 44499, dtype: int64], [array([0]), x    0
# Name: 44500, dtype: int64], [array([0]), x    0
# Name: 44501, dtype: int64], [array([0]), x    0
# Name: 44502, dtype: int64], [array([0]), x    0
# Name: 44503, dtype: int64], [array([0]), x    0
# Name: 44504, dtype: int64], [array([0]), x    0
# Name: 44505, dtype: int64], [array([0]), x    0
# Name: 44506, dtype: int64], [array([0]), x    0
# Name: 44507, dtype: int64], [array([0]), x    0
# Name: 44508, dtype: int64], [array([0]), x    0
# Name: 44509, dtype: int64], [array([0]), x    0
# Name: 44510, dtype: int64], [array([0]), x    0
# Name: 44511, dtype: int64], [array([0]), x    0
# Name: 44512, dtype: int64], [array([0]), x    0
# Name: 44513, dtype: int64], [array([0]), x    0
# Name: 44514, dtype: int64], [array([0]), x    0
# Name: 44515, dtype: int64], [array([0]), x    0
# Name: 44516, dtype: int64], [array([0]), x    0
# Name: 44517, dtype: int64], [array([0]), x    0
# Name: 44518, dtype: int64], [array([0]), x    0
# Name: 44519, dtype: int64], [array([0]), x    0
# Name: 44520, dtype: int64], [array([0]), x    0
# Name: 44521, dtype: int64], [array([0]), x    0
# Name: 44522, dtype: int64], [array([0]), x    0
# Name: 44523, dtype: int64], [array([0]), x    0
# Name: 44524, dtype: int64], [array([0]), x    0
# Name: 44525, dtype: int64], [array([0]), x    0
# Name: 44526, dtype: int64], [array([0]), x    0
# Name: 44527, dtype: int64], [array([0]), x    0
# Name: 44528, dtype: int64], [array([0]), x    0
# Name: 44529, dtype: int64], [array([0]), x    0
# Name: 44530, dtype: int64], [array([0]), x    0
# Name: 44531, dtype: int64], [array([0]), x    0
# Name: 44532, dtype: int64], [array([0]), x    0
# Name: 44533, dtype: int64], [array([0]), x    0
# Name: 44534, dtype: int64], [array([0]), x    0
# Name: 44535, dtype: int64], [array([0]), x    0
# Name: 44536, dtype: int64], [array([0]), x    0
# Name: 44537, dtype: int64], [array([0]), x    0
# Name: 44538, dtype: int64], [array([0]), x    0
# Name: 44539, dtype: int64], [array([0]), x    0
# Name: 44540, dtype: int64], [array([0]), x    0
# Name: 44541, dtype: int64], [array([0]), x    0
# Name: 44542, dtype: int64], [array([0]), x    0
# Name: 44543, dtype: int64], [array([0]), x    0
# Name: 44544, dtype: int64], [array([1]), x    1
# Name: 44545, dtype: int64], [array([0]), x    0
# Name: 44546, dtype: int64], [array([0]), x    0
# Name: 44547, dtype: int64], [array([0]), x    0
# Name: 44548, dtype: int64], [array([0]), x    0
# Name: 44549, dtype: int64], [array([0]), x    0
# Name: 44550, dtype: int64], [array([0]), x    0
# Name: 44551, dtype: int64], [array([0]), x    0
# Name: 44552, dtype: int64], [array([0]), x    0
# Name: 44553, dtype: int64], [array([0]), x    0
# Name: 44554, dtype: int64], [array([0]), x    0
# Name: 44555, dtype: int64], [array([0]), x    0
# Name: 44556, dtype: int64], [array([0]), x    0
# Name: 44557, dtype: int64], [array([0]), x    0
# Name: 44558, dtype: int64], [array([0]), x    0
# Name: 44559, dtype: int64], [array([0]), x    0
# Name: 44560, dtype: int64], [array([0]), x    0
# Name: 44561, dtype: int64], [array([0]), x    0
# Name: 44562, dtype: int64], [array([0]), x    0
# Name: 44563, dtype: int64], [array([0]), x    0
# Name: 44564, dtype: int64], [array([0]), x    0
# Name: 44565, dtype: int64], [array([0]), x    0
# Name: 44566, dtype: int64], [array([0]), x    0
# Name: 44567, dtype: int64], [array([0]), x    0
# Name: 44568, dtype: int64], [array([0]), x    0
# Name: 44569, dtype: int64], [array([0]), x    0
# Name: 44570, dtype: int64], [array([0]), x    0
# Name: 44571, dtype: int64], [array([0]), x    0
# Name: 44572, dtype: int64], [array([0]), x    0
# Name: 44573, dtype: int64], [array([0]), x    0
# Name: 44574, dtype: int64], [array([0]), x    0
# Name: 44575, dtype: int64], [array([0]), x    0
# Name: 44576, dtype: int64], [array([0]), x    0
# Name: 44577, dtype: int64], [array([0]), x    0
# Name: 44578, dtype: int64], [array([1]), x    1
# Name: 44579, dtype: int64], [array([1]), x    1
# Name: 44580, dtype: int64], [array([0]), x    0
# Name: 44581, dtype: int64], [array([1]), x    1
# Name: 44582, dtype: int64], [array([1]), x    1
# Name: 44583, dtype: int64], [array([1]), x    1
# Name: 44584, dtype: int64], [array([1]), x    1
# Name: 44585, dtype: int64], [array([1]), x    1
# Name: 44586, dtype: int64], [array([1]), x    1
# Name: 44587, dtype: int64], [array([1]), x    1
# Name: 44588, dtype: int64], [array([1]), x    1
# Name: 44589, dtype: int64], [array([1]), x    1
# Name: 44590, dtype: int64], [array([1]), x    1
# Name: 44591, dtype: int64], [array([0]), x    0
# Name: 44592, dtype: int64], [array([1]), x    1
# Name: 44593, dtype: int64], [array([0]), x    0
# Name: 44594, dtype: int64], [array([1]), x    1
# Name: 44595, dtype: int64], [array([0]), x    0
# Name: 44596, dtype: int64], [array([0]), x    0
# Name: 44597, dtype: int64], [array([0]), x    0
# Name: 44598, dtype: int64], [array([0]), x    0
# Name: 44599, dtype: int64], [array([0]), x    0
# Name: 44600, dtype: int64], [array([0]), x    0
# Name: 44601, dtype: int64], [array([0]), x    0
# Name: 44602, dtype: int64], [array([0]), x    0
# Name: 44603, dtype: int64], [array([0]), x    0
# Name: 44604, dtype: int64], [array([0]), x    0
# Name: 44605, dtype: int64], [array([0]), x    0
# Name: 44606, dtype: int64], [array([1]), x    1
# Name: 44607, dtype: int64], [array([1]), x    1
# Name: 44608, dtype: int64], [array([0]), x    0
# Name: 44609, dtype: int64], [array([0]), x    0
# Name: 44610, dtype: int64], [array([0]), x    0
# Name: 44611, dtype: int64], [array([0]), x    0
# Name: 44612, dtype: int64], [array([0]), x    0
# Name: 44613, dtype: int64], [array([1]), x    1
# Name: 44614, dtype: int64], [array([0]), x    0
# Name: 44615, dtype: int64], [array([0]), x    0
# Name: 44616, dtype: int64], [array([0]), x    0
# Name: 44617, dtype: int64], [array([0]), x    0
# Name: 44618, dtype: int64], [array([0]), x    0
# Name: 44619, dtype: int64], [array([0]), x    0
# Name: 44620, dtype: int64], [array([0]), x    0
# Name: 44621, dtype: int64], [array([0]), x    0
# Name: 44622, dtype: int64], [array([0]), x    0
# Name: 44623, dtype: int64], [array([0]), x    0
# Name: 44624, dtype: int64], [array([0]), x    0
# Name: 44625, dtype: int64], [array([0]), x    0
# Name: 44626, dtype: int64], [array([0]), x    0
# Name: 44627, dtype: int64], [array([0]), x    0
# Name: 44628, dtype: int64], [array([0]), x    0
# Name: 44629, dtype: int64], [array([0]), x    0
# Name: 44630, dtype: int64], [array([0]), x    0
# Name: 44631, dtype: int64], [array([0]), x    0
# Name: 44632, dtype: int64], [array([0]), x    0
# Name: 44633, dtype: int64], [array([0]), x    0
# Name: 44634, dtype: int64], [array([0]), x    0
# Name: 44635, dtype: int64], [array([0]), x    0
# Name: 44636, dtype: int64], [array([0]), x    0
# Name: 44637, dtype: int64], [array([0]), x    0
# Name: 44638, dtype: int64], [array([0]), x    0
# Name: 44639, dtype: int64], [array([0]), x    0
# Name: 44640, dtype: int64], [array([0]), x    0
# Name: 44641, dtype: int64], [array([0]), x    0
# Name: 44642, dtype: int64], [array([0]), x    0
# Name: 44643, dtype: int64], [array([0]), x    0
# Name: 44644, dtype: int64], [array([0]), x    0
# Name: 44645, dtype: int64], [array([0]), x    0
# Name: 44646, dtype: int64], [array([0]), x    0
# Name: 44647, dtype: int64], [array([0]), x    0
# Name: 44648, dtype: int64], [array([0]), x    0
# Name: 44649, dtype: int64], [array([0]), x    0
# Name: 44650, dtype: int64], [array([0]), x    0
# Name: 44651, dtype: int64], [array([0]), x    0
# Name: 44652, dtype: int64], [array([0]), x    0
# Name: 44653, dtype: int64], [array([0]), x    0
# Name: 44654, dtype: int64], [array([0]), x    0
# Name: 44655, dtype: int64], [array([0]), x    0
# Name: 44656, dtype: int64], [array([0]), x    0
# Name: 44657, dtype: int64], [array([0]), x    0
# Name: 44658, dtype: int64], [array([0]), x    0
# Name: 44659, dtype: int64], [array([0]), x    0
# Name: 44660, dtype: int64], [array([0]), x    0
# Name: 44661, dtype: int64], [array([0]), x    0
# Name: 44662, dtype: int64], [array([0]), x    0
# Name: 44663, dtype: int64], [array([0]), x    0
# Name: 44664, dtype: int64], [array([0]), x    0
# Name: 44665, dtype: int64], [array([0]), x    0
# Name: 44666, dtype: int64], [array([0]), x    0
# Name: 44667, dtype: int64], [array([0]), x    0
# Name: 44668, dtype: int64], [array([0]), x    0
# Name: 44669, dtype: int64], [array([0]), x    0
# Name: 44670, dtype: int64], [array([0]), x    0
# Name: 44671, dtype: int64], [array([0]), x    0
# Name: 44672, dtype: int64], [array([1]), x    1
# Name: 44673, dtype: int64], [array([0]), x    0
# Name: 44674, dtype: int64], [array([0]), x    0
# Name: 44675, dtype: int64], [array([0]), x    0
# Name: 44676, dtype: int64], [array([0]), x    0
# Name: 44677, dtype: int64], [array([0]), x    0
# Name: 44678, dtype: int64], [array([0]), x    0
# Name: 44679, dtype: int64], [array([0]), x    0
# Name: 44680, dtype: int64], [array([0]), x    0
# Name: 44681, dtype: int64], [array([0]), x    0
# Name: 44682, dtype: int64], [array([0]), x    0
# Name: 44683, dtype: int64], [array([0]), x    0
# Name: 44684, dtype: int64], [array([0]), x    0
# Name: 44685, dtype: int64], [array([0]), x    0
# Name: 44686, dtype: int64], [array([0]), x    0
# Name: 44687, dtype: int64], [array([0]), x    0
# Name: 44688, dtype: int64], [array([0]), x    0
# Name: 44689, dtype: int64], [array([0]), x    0
# Name: 44690, dtype: int64], [array([0]), x    0
# Name: 44691, dtype: int64], [array([0]), x    0
# Name: 44692, dtype: int64], [array([0]), x    0
# Name: 44693, dtype: int64], [array([0]), x    0
# Name: 44694, dtype: int64], [array([0]), x    0
# Name: 44695, dtype: int64], [array([0]), x    0
# Name: 44696, dtype: int64], [array([0]), x    0
# Name: 44697, dtype: int64], [array([0]), x    0
# Name: 44698, dtype: int64], [array([0]), x    0
# Name: 44699, dtype: int64], [array([0]), x    0
# Name: 44700, dtype: int64], [array([0]), x    0
# Name: 44701, dtype: int64], [array([0]), x    0
# Name: 44702, dtype: int64], [array([0]), x    0
# Name: 44703, dtype: int64], [array([0]), x    0
# Name: 44704, dtype: int64], [array([0]), x    0
# Name: 44705, dtype: int64], [array([0]), x    0
# Name: 44706, dtype: int64], [array([0]), x    0
# Name: 44707, dtype: int64], [array([0]), x    0
# Name: 44708, dtype: int64], [array([0]), x    0
# Name: 44709, dtype: int64], [array([0]), x    0
# Name: 44710, dtype: int64], [array([0]), x    0
# Name: 44711, dtype: int64], [array([0]), x    0
# Name: 44712, dtype: int64], [array([0]), x    0
# Name: 44713, dtype: int64], [array([0]), x    0
# Name: 44714, dtype: int64], [array([0]), x    0
# Name: 44715, dtype: int64], [array([0]), x    0
# Name: 44716, dtype: int64], [array([0]), x    0
# Name: 44717, dtype: int64], [array([0]), x    0
# Name: 44718, dtype: int64], [array([0]), x    0
# Name: 44719, dtype: int64], [array([0]), x    0
# Name: 44720, dtype: int64], [array([0]), x    0
# Name: 44721, dtype: int64], [array([0]), x    0
# Name: 44722, dtype: int64], [array([0]), x    0
# Name: 44723, dtype: int64], [array([0]), x    0
# Name: 44724, dtype: int64], [array([0]), x    0
# Name: 44725, dtype: int64], [array([0]), x    0
# Name: 44726, dtype: int64], [array([0]), x    0
# Name: 44727, dtype: int64], [array([0]), x    0
# Name: 44728, dtype: int64], [array([0]), x    0
# Name: 44729, dtype: int64], [array([0]), x    0
# Name: 44730, dtype: int64], [array([0]), x    0
# Name: 44731, dtype: int64], [array([0]), x    0
# Name: 44732, dtype: int64], [array([0]), x    0
# Name: 44733, dtype: int64], [array([0]), x    0
# Name: 44734, dtype: int64], [array([0]), x    0
# Name: 44735, dtype: int64], [array([0]), x    0
# Name: 44736, dtype: int64], [array([0]), x    0
# Name: 44737, dtype: int64], [array([0]), x    0
# Name: 44738, dtype: int64], [array([0]), x    0
# Name: 44739, dtype: int64], [array([0]), x    0
# Name: 44740, dtype: int64], [array([0]), x    0
# Name: 44741, dtype: int64], [array([0]), x    0
# Name: 44742, dtype: int64], [array([0]), x    0
# Name: 44743, dtype: int64], [array([0]), x    0
# Name: 44744, dtype: int64], [array([0]), x    0
# Name: 44745, dtype: int64], [array([0]), x    0
# Name: 44746, dtype: int64], [array([0]), x    0
# Name: 44747, dtype: int64], [array([0]), x    0
# Name: 44748, dtype: int64], [array([0]), x    0
# Name: 44749, dtype: int64], [array([0]), x    0
# Name: 44750, dtype: int64], [array([0]), x    0
# Name: 44751, dtype: int64], [array([0]), x    0
# Name: 44752, dtype: int64], [array([0]), x    0
# Name: 44753, dtype: int64], [array([0]), x    0
# Name: 44754, dtype: int64], [array([0]), x    0
# Name: 44755, dtype: int64], [array([0]), x    0
# Name: 44756, dtype: int64], [array([0]), x    0
# Name: 44757, dtype: int64], [array([0]), x    0
# Name: 44758, dtype: int64], [array([0]), x    0
# Name: 44759, dtype: int64], [array([0]), x    0
# Name: 44760, dtype: int64], [array([0]), x    0
# Name: 44761, dtype: int64], [array([0]), x    0
# Name: 44762, dtype: int64], [array([0]), x    0
# Name: 44763, dtype: int64], [array([0]), x    0
# Name: 44764, dtype: int64], [array([0]), x    0
# Name: 44765, dtype: int64], [array([0]), x    0
# Name: 44766, dtype: int64], [array([0]), x    0
# Name: 44767, dtype: int64], [array([0]), x    0
# Name: 44768, dtype: int64], [array([0]), x    0
# Name: 44769, dtype: int64], [array([0]), x    0
# Name: 44770, dtype: int64], [array([0]), x    0
# Name: 44771, dtype: int64], [array([0]), x    0
# Name: 44772, dtype: int64], [array([0]), x    0
# Name: 44773, dtype: int64], [array([0]), x    0
# Name: 44774, dtype: int64], [array([0]), x    0
# Name: 44775, dtype: int64], [array([0]), x    0
# Name: 44776, dtype: int64], [array([0]), x    0
# Name: 44777, dtype: int64], [array([0]), x    0
# Name: 44778, dtype: int64], [array([0]), x    0
# Name: 44779, dtype: int64], [array([0]), x    0
# Name: 44780, dtype: int64], [array([0]), x    0
# Name: 44781, dtype: int64], [array([1]), x    1
# Name: 44782, dtype: int64], [array([0]), x    0
# Name: 44783, dtype: int64], [array([0]), x    0
# Name: 44784, dtype: int64], [array([0]), x    0
# Name: 44785, dtype: int64], [array([0]), x    0
# Name: 44786, dtype: int64], [array([0]), x    0
# Name: 44787, dtype: int64], [array([0]), x    0
# Name: 44788, dtype: int64], [array([0]), x    0
# Name: 44789, dtype: int64], [array([0]), x    0
# Name: 44790, dtype: int64], [array([0]), x    0
# Name: 44791, dtype: int64], [array([0]), x    0
# Name: 44792, dtype: int64], [array([1]), x    1
# Name: 44793, dtype: int64], [array([0]), x    0
# Name: 44794, dtype: int64], [array([0]), x    0
# Name: 44795, dtype: int64], [array([0]), x    0
# Name: 44796, dtype: int64], [array([0]), x    0
# Name: 44797, dtype: int64], [array([0]), x    0
# Name: 44798, dtype: int64], [array([0]), x    0
# Name: 44799, dtype: int64], [array([1]), x    1
# Name: 44800, dtype: int64], [array([0]), x    0
# Name: 44801, dtype: int64], [array([0]), x    0
# Name: 44802, dtype: int64], [array([0]), x    0
# Name: 44803, dtype: int64], [array([0]), x    0
# Name: 44804, dtype: int64], [array([0]), x    0
# Name: 44805, dtype: int64], [array([0]), x    0
# Name: 44806, dtype: int64], [array([0]), x    0
# Name: 44807, dtype: int64], [array([0]), x    0
# Name: 44808, dtype: int64], [array([0]), x    0
# Name: 44809, dtype: int64]]
